# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/Craft/CRAFT')

# %%
# !pip install scikit-image==0.18.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-image==0.18.0
#   Downloading scikit-image-0.18.0.tar.gz (36.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 20.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.18.0) (1.22.4)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.18.0) (1.10.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.18.0) (3.7.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.18.0) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.18.0) (8.4.0)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.18.0) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.18.0) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.18.0) (1.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.0) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.0) (1.16.0)
# Building wheels for collected packages: scikit-image
#   Building wheel for scikit-image (pyproject.toml) ... done
#   Created wheel for scikit-image: filename=scikit_image-0.18.0-cp310-cp310-linux_x86_64.whl size=35691796 sha256=46fdb53dbac2faf1a577b5a20551e16e32b0b1fe57a26bbeb99bcf13291faab7
#   Stored in directory: /root/.cache/pip/wheels/81/21/b4/bea1d12869cffd23f9d1e353b69240238d05ad4e62f57ff6ce
# Successfully built scikit-image
# Installing collected packages: scikit-image
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
# Successfully installed scikit-image-0.18.0

# %%
# !pip install numpy --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Collecting numpy
#   Using cached numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.3 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.3 which is incompatible.
# Successfully installed numpy-1.24.3

# %%
# !CUDA_VISIBLE_DEVICES=0,1,2 python finetune.py
# Out:
# len trainset is 2200
# region loss is 0.010204105637967587, affinity loss is 0.016642976552248
# Epoch is [1/20], mini-batch is [1/275], time consumption is 1684806074.593589, batch_loss is 0.026847
# region loss is 0.020590169355273247, affinity loss is 0.026100439950823784
# Epoch is [1/20], mini-batch is [2/275], time consumption is 11.562539, batch_loss is 0.046691
# region loss is 0.006671174895018339, affinity loss is 0.009950477629899979
# Epoch is [1/20], mini-batch is [3/275], time consumption is 8.804304, batch_loss is 0.016622
# region loss is 0.013645749539136887, affinity loss is 0.01780235394835472
# Epoch is [1/20], mini-batch is [4/275], time consumption is 12.203418, batch_loss is 0.031448
# region loss is 0.0063437591306865215, affinity loss is 0.010425531305372715
# Epoch is [1/20], mini-batch is [5/275], time consumption is 10.988464, batch_loss is 0.016769
# Tue May 23 01:42:00 2023
# region loss is 0.014636158011853695, affinity loss is 0.01705566979944706
# Epoch is [1/20], mini-batch is [6/275], time consumption is 9.600112, batch_loss is 0.031692
# region loss is 0.012676781974732876, affinity loss is 0.01138582918792963
# Epoch is [1/20], mini-batch is [7/275], time consumption is 10.078987, batch_loss is 0.024063
# region loss is 0.03333103656768799, affinity loss is 0.02858111262321472
# Epoch is [1/20], mini-batch is [8/275], time consumption is 11.327661, batch_loss is 0.061912
# region loss is 0.009560773149132729, affinity loss is 0.011871693655848503
# Epoch is [1/20], mini-batch is [9/275], time consumption is 10.384961, batch_loss is 0.021432
# region loss is 0.012111427262425423, affinity loss is 0.012358644045889378
# Epoch is [1/20], mini-batch is [10/275], time consumption is 8.088031, batch_loss is 0.024470
# Tue May 23 01:42:51 2023
# region loss is 0.008112556301057339, affinity loss is 0.009439324960112572
# Epoch is [1/20], mini-batch is [11/275], time consumption is 11.399929, batch_loss is 0.017552
# region loss is 0.011132128536701202, affinity loss is 0.008203535340726376
# Epoch is [1/20], mini-batch is [12/275], time consumption is 8.372501, batch_loss is 0.019336
# region loss is 0.005992908030748367, affinity loss is 0.010940035805106163
# Epoch is [1/20], mini-batch is [13/275], time consumption is 9.220858, batch_loss is 0.016933
# region loss is 0.012718153186142445, affinity loss is 0.019329408183693886
# Epoch is [1/20], mini-batch is [14/275], time consumption is 9.113394, batch_loss is 0.032048
# region loss is 0.01308357808738947, affinity loss is 0.01718834415078163
# Epoch is [1/20], mini-batch is [15/275], time consumption is 12.164027, batch_loss is 0.030272
# Tue May 23 01:43:44 2023
# region loss is 0.00902247242629528, affinity loss is 0.011625023558735847
# Epoch is [1/20], mini-batch is [16/275], time consumption is 8.935342, batch_loss is 0.020647
# region loss is 0.03429865464568138, affinity loss is 0.02507156692445278
# Epoch is [1/20], mini-batch is [17/275], time consumption is 9.028072, batch_loss is 0.059370
# region loss is 0.011461100541055202, affinity loss is 0.018591314554214478
# Epoch is [1/20], mini-batch is [18/275], time consumption is 9.833204, batch_loss is 0.030052
# region loss is 0.030412623658776283, affinity loss is 0.02463514544069767
# Epoch is [1/20], mini-batch is [19/275], time consumption is 9.483684, batch_loss is 0.055048
# region loss is 0.008949157781898975, affinity loss is 0.01270428765565157
# Epoch is [1/20], mini-batch is [20/275], time consumption is 15.262223, batch_loss is 0.021653
# Tue May 23 01:44:39 2023
# region loss is 0.007334984373301268, affinity loss is 0.008497415110468864
# Epoch is [1/20], mini-batch is [21/275], time consumption is 9.758960, batch_loss is 0.015832
# region loss is 0.00796642154455185, affinity loss is 0.01187852118164301
# Epoch is [1/20], mini-batch is [22/275], time consumption is 10.375020, batch_loss is 0.019845
# region loss is 0.013052038848400116, affinity loss is 0.013963857665657997
# Epoch is [1/20], mini-batch is [23/275], time consumption is 8.320787, batch_loss is 0.027016
# region loss is 0.010216041468083858, affinity loss is 0.011324934661388397
# Epoch is [1/20], mini-batch is [24/275], time consumption is 10.566800, batch_loss is 0.021541
# region loss is 0.008568099699914455, affinity loss is 0.012340451590716839
# Epoch is [1/20], mini-batch is [25/275], time consumption is 8.932928, batch_loss is 0.020909
# Tue May 23 01:45:29 2023
# region loss is 0.014982154592871666, affinity loss is 0.01805199682712555
# Epoch is [1/20], mini-batch is [26/275], time consumption is 9.635643, batch_loss is 0.033034
# region loss is 0.00869058258831501, affinity loss is 0.010394490323960781
# Epoch is [1/20], mini-batch is [27/275], time consumption is 9.689291, batch_loss is 0.019085
# region loss is 0.006683744955807924, affinity loss is 0.007238261867314577
# Epoch is [1/20], mini-batch is [28/275], time consumption is 8.691833, batch_loss is 0.013922
# region loss is 0.013124789111316204, affinity loss is 0.015644650906324387
# Epoch is [1/20], mini-batch is [29/275], time consumption is 9.792211, batch_loss is 0.028769
# region loss is 0.021815801039338112, affinity loss is 0.020875755697488785
# Epoch is [1/20], mini-batch is [30/275], time consumption is 8.817654, batch_loss is 0.042692
# Tue May 23 01:46:17 2023
# region loss is 0.01784352958202362, affinity loss is 0.03158968687057495
# Epoch is [1/20], mini-batch is [31/275], time consumption is 9.325051, batch_loss is 0.049433
# region loss is 0.012692991644144058, affinity loss is 0.010559624060988426
# Epoch is [1/20], mini-batch is [32/275], time consumption is 8.854018, batch_loss is 0.023253
# region loss is 0.009064904414117336, affinity loss is 0.015103100799024105
# Epoch is [1/20], mini-batch is [33/275], time consumption is 9.385863, batch_loss is 0.024168
# region loss is 0.01764068193733692, affinity loss is 0.018179569393396378
# Epoch is [1/20], mini-batch is [34/275], time consumption is 10.627168, batch_loss is 0.035820
# region loss is 0.01818767376244068, affinity loss is 0.016096876934170723
# Epoch is [1/20], mini-batch is [35/275], time consumption is 9.724374, batch_loss is 0.034285
# Tue May 23 01:47:07 2023
# region loss is 0.005927181802690029, affinity loss is 0.007996389642357826
# Epoch is [1/20], mini-batch is [36/275], time consumption is 9.945828, batch_loss is 0.013924
# region loss is 0.012972438707947731, affinity loss is 0.0142652103677392
# Epoch is [1/20], mini-batch is [37/275], time consumption is 9.689038, batch_loss is 0.027238
# region loss is 0.012603693641722202, affinity loss is 0.012823655270040035
# Epoch is [1/20], mini-batch is [38/275], time consumption is 9.283922, batch_loss is 0.025427
# region loss is 0.005366037134081125, affinity loss is 0.008432147093117237
# Epoch is [1/20], mini-batch is [39/275], time consumption is 9.408971, batch_loss is 0.013798
# region loss is 0.006907088682055473, affinity loss is 0.008128862828016281
# Epoch is [1/20], mini-batch is [40/275], time consumption is 9.501335, batch_loss is 0.015036
# Tue May 23 01:47:57 2023
# region loss is 0.007302518934011459, affinity loss is 0.012792153283953667
# Epoch is [1/20], mini-batch is [41/275], time consumption is 9.171784, batch_loss is 0.020095
# region loss is 0.01759134605526924, affinity loss is 0.023269031196832657
# Epoch is [1/20], mini-batch is [42/275], time consumption is 9.081401, batch_loss is 0.040860
# region loss is 0.008887190371751785, affinity loss is 0.011765727773308754
# Epoch is [1/20], mini-batch is [43/275], time consumption is 13.982487, batch_loss is 0.020653
# region loss is 0.0066025289706885815, affinity loss is 0.007351650856435299
# Epoch is [1/20], mini-batch is [44/275], time consumption is 9.477877, batch_loss is 0.013954
# region loss is 0.019001329317688942, affinity loss is 0.02116801217198372
# Epoch is [1/20], mini-batch is [45/275], time consumption is 8.311290, batch_loss is 0.040169
# Tue May 23 01:48:50 2023
# region loss is 0.017988016828894615, affinity loss is 0.014604531228542328
# Epoch is [1/20], mini-batch is [46/275], time consumption is 9.387797, batch_loss is 0.032593
# region loss is 0.017413869500160217, affinity loss is 0.014737939462065697
# Epoch is [1/20], mini-batch is [47/275], time consumption is 9.194795, batch_loss is 0.032152
# region loss is 0.012487011961638927, affinity loss is 0.012942231260240078
# Epoch is [1/20], mini-batch is [48/275], time consumption is 8.470921, batch_loss is 0.025429
# region loss is 0.010874101892113686, affinity loss is 0.014634196646511555
# Epoch is [1/20], mini-batch is [49/275], time consumption is 8.902178, batch_loss is 0.025508
# region loss is 0.01706184633076191, affinity loss is 0.031931426376104355
# Epoch is [1/20], mini-batch is [50/275], time consumption is 12.896646, batch_loss is 0.048993
# Tue May 23 01:49:41 2023
# region loss is 0.029227906838059425, affinity loss is 0.031796444207429886
# Epoch is [1/20], mini-batch is [51/275], time consumption is 10.254234, batch_loss is 0.061024
# region loss is 0.00955885648727417, affinity loss is 0.010590878315269947
# Epoch is [1/20], mini-batch is [52/275], time consumption is 10.036139, batch_loss is 0.020150
# region loss is 0.010917415842413902, affinity loss is 0.013694530352950096
# Epoch is [1/20], mini-batch is [53/275], time consumption is 9.514320, batch_loss is 0.024612
# region loss is 0.03224930912256241, affinity loss is 0.02055424451828003
# Epoch is [1/20], mini-batch is [54/275], time consumption is 10.568791, batch_loss is 0.052804
# region loss is 0.005272096488624811, affinity loss is 0.009575745090842247
# Epoch is [1/20], mini-batch is [55/275], time consumption is 10.023539, batch_loss is 0.014848
# Tue May 23 01:50:33 2023
# region loss is 0.00816384982317686, affinity loss is 0.010107055306434631
# Epoch is [1/20], mini-batch is [56/275], time consumption is 12.503361, batch_loss is 0.018271
# region loss is 0.01287897676229477, affinity loss is 0.015731705352663994
# Epoch is [1/20], mini-batch is [57/275], time consumption is 8.855275, batch_loss is 0.028611
# region loss is 0.00836609210819006, affinity loss is 0.020120088011026382
# Epoch is [1/20], mini-batch is [58/275], time consumption is 11.127080, batch_loss is 0.028486
# region loss is 0.007709010969847441, affinity loss is 0.012716487050056458
# Epoch is [1/20], mini-batch is [59/275], time consumption is 8.680644, batch_loss is 0.020425
# region loss is 0.014765666797757149, affinity loss is 0.011399989947676659
# Epoch is [1/20], mini-batch is [60/275], time consumption is 9.580813, batch_loss is 0.026166
# Tue May 23 01:51:26 2023
# region loss is 0.0052664801478385925, affinity loss is 0.008692262694239616
# Epoch is [1/20], mini-batch is [61/275], time consumption is 8.591892, batch_loss is 0.013959
# region loss is 0.00811699777841568, affinity loss is 0.013820762746036053
# Epoch is [1/20], mini-batch is [62/275], time consumption is 13.762246, batch_loss is 0.021938
# region loss is 0.009310796856880188, affinity loss is 0.01726691983640194
# Epoch is [1/20], mini-batch is [63/275], time consumption is 9.529136, batch_loss is 0.026578
# region loss is 0.007630533538758755, affinity loss is 0.011856749653816223
# Epoch is [1/20], mini-batch is [64/275], time consumption is 9.404833, batch_loss is 0.019487
# region loss is 0.012308700941503048, affinity loss is 0.013500318862497807
# Epoch is [1/20], mini-batch is [65/275], time consumption is 9.449421, batch_loss is 0.025809
# Tue May 23 01:52:19 2023
# region loss is 0.004162784665822983, affinity loss is 0.008188954554498196
# Epoch is [1/20], mini-batch is [66/275], time consumption is 10.361882, batch_loss is 0.012352
# region loss is 0.009627402760088444, affinity loss is 0.013127610087394714
# Epoch is [1/20], mini-batch is [67/275], time consumption is 8.064588, batch_loss is 0.022755
# region loss is 0.010554071515798569, affinity loss is 0.011974917724728584
# Epoch is [1/20], mini-batch is [68/275], time consumption is 9.231731, batch_loss is 0.022529
# region loss is 0.009651332162320614, affinity loss is 0.015279984101653099
# Epoch is [1/20], mini-batch is [69/275], time consumption is 10.173718, batch_loss is 0.024931
# region loss is 0.0075485133565962315, affinity loss is 0.01142642367631197
# Epoch is [1/20], mini-batch is [70/275], time consumption is 9.350007, batch_loss is 0.018975
# Tue May 23 01:53:08 2023
# region loss is 0.007084225304424763, affinity loss is 0.010152498260140419
# Epoch is [1/20], mini-batch is [71/275], time consumption is 9.870471, batch_loss is 0.017237
# region loss is 0.010335282422602177, affinity loss is 0.01293855905532837
# Epoch is [1/20], mini-batch is [72/275], time consumption is 9.398460, batch_loss is 0.023274
# region loss is 0.010983330197632313, affinity loss is 0.012204255908727646
# Epoch is [1/20], mini-batch is [73/275], time consumption is 9.875032, batch_loss is 0.023188
# region loss is 0.006814604625105858, affinity loss is 0.012660385109484196
# Epoch is [1/20], mini-batch is [74/275], time consumption is 10.124906, batch_loss is 0.019475
# region loss is 0.009227690286934376, affinity loss is 0.013483240269124508
# Epoch is [1/20], mini-batch is [75/275], time consumption is 11.005815, batch_loss is 0.022711
# Tue May 23 01:54:01 2023
# region loss is 0.007343202363699675, affinity loss is 0.010299802757799625
# Epoch is [1/20], mini-batch is [76/275], time consumption is 11.904839, batch_loss is 0.017643
# region loss is 0.007279773708432913, affinity loss is 0.009501923806965351
# Epoch is [1/20], mini-batch is [77/275], time consumption is 12.360682, batch_loss is 0.016782
# region loss is 0.015052233822643757, affinity loss is 0.018219489604234695
# Epoch is [1/20], mini-batch is [78/275], time consumption is 11.949219, batch_loss is 0.033272
# region loss is 0.008207537233829498, affinity loss is 0.012064635753631592
# Epoch is [1/20], mini-batch is [79/275], time consumption is 9.412033, batch_loss is 0.020272
# region loss is 0.0064648110419511795, affinity loss is 0.008268100209534168
# Epoch is [1/20], mini-batch is [80/275], time consumption is 9.925328, batch_loss is 0.014733
# Tue May 23 01:54:59 2023
# region loss is 0.005659860093146563, affinity loss is 0.008650864474475384
# Epoch is [1/20], mini-batch is [81/275], time consumption is 9.187256, batch_loss is 0.014311
# region loss is 0.009039782918989658, affinity loss is 0.013269946910440922
# Epoch is [1/20], mini-batch is [82/275], time consumption is 8.727453, batch_loss is 0.022310
# region loss is 0.009132727049291134, affinity loss is 0.015301397070288658
# Epoch is [1/20], mini-batch is [83/275], time consumption is 8.050303, batch_loss is 0.024434
# region loss is 0.008072110824286938, affinity loss is 0.00809953361749649
# Epoch is [1/20], mini-batch is [84/275], time consumption is 9.285114, batch_loss is 0.016172
# region loss is 0.011396183632314205, affinity loss is 0.01521534938365221
# Epoch is [1/20], mini-batch is [85/275], time consumption is 13.614608, batch_loss is 0.026612
# Tue May 23 01:55:50 2023
# region loss is 0.00835995189845562, affinity loss is 0.012025199830532074
# Epoch is [1/20], mini-batch is [86/275], time consumption is 9.675668, batch_loss is 0.020385
# region loss is 0.018307548016309738, affinity loss is 0.020809320732951164
# Epoch is [1/20], mini-batch is [87/275], time consumption is 9.540754, batch_loss is 0.039117
# region loss is 0.009426457807421684, affinity loss is 0.012271864339709282
# Epoch is [1/20], mini-batch is [88/275], time consumption is 9.573002, batch_loss is 0.021698
# region loss is 0.007178053259849548, affinity loss is 0.01607697084546089
# Epoch is [1/20], mini-batch is [89/275], time consumption is 8.469940, batch_loss is 0.023255
# region loss is 0.008172237314283848, affinity loss is 0.008813302963972092
# Epoch is [1/20], mini-batch is [90/275], time consumption is 8.309490, batch_loss is 0.016986
# Tue May 23 01:56:37 2023
# region loss is 0.0056930361315608025, affinity loss is 0.007827023044228554
# Epoch is [1/20], mini-batch is [91/275], time consumption is 9.138782, batch_loss is 0.013520
# region loss is 0.01173700112849474, affinity loss is 0.011518225073814392
# Epoch is [1/20], mini-batch is [92/275], time consumption is 9.761900, batch_loss is 0.023255
# region loss is 0.009114575572311878, affinity loss is 0.015551538206636906
# Epoch is [1/20], mini-batch is [93/275], time consumption is 11.221363, batch_loss is 0.024666
# region loss is 0.007116784807294607, affinity loss is 0.011679872870445251
# Epoch is [1/20], mini-batch is [94/275], time consumption is 9.703588, batch_loss is 0.018797
# region loss is 0.011508562602102757, affinity loss is 0.01567276380956173
# Epoch is [1/20], mini-batch is [95/275], time consumption is 9.000305, batch_loss is 0.027181
# Tue May 23 01:57:29 2023
# region loss is 0.005740902852267027, affinity loss is 0.008812795393168926
# Epoch is [1/20], mini-batch is [96/275], time consumption is 11.861908, batch_loss is 0.014554
# region loss is 0.007248317822813988, affinity loss is 0.013153595849871635
# Epoch is [1/20], mini-batch is [97/275], time consumption is 8.862425, batch_loss is 0.020402
# region loss is 0.018247105181217194, affinity loss is 0.020322732627391815
# Epoch is [1/20], mini-batch is [98/275], time consumption is 8.907250, batch_loss is 0.038570
# region loss is 0.007055743131786585, affinity loss is 0.00911489874124527
# Epoch is [1/20], mini-batch is [99/275], time consumption is 8.947300, batch_loss is 0.016171
# region loss is 0.008246890269219875, affinity loss is 0.011425833217799664
# Epoch is [1/20], mini-batch is [100/275], time consumption is 9.253525, batch_loss is 0.019673
# Tue May 23 01:58:18 2023
# region loss is 0.015369471162557602, affinity loss is 0.015981510281562805
# Epoch is [1/20], mini-batch is [101/275], time consumption is 9.174347, batch_loss is 0.031351
# region loss is 0.00602125097066164, affinity loss is 0.009208428673446178
# Epoch is [1/20], mini-batch is [102/275], time consumption is 9.091849, batch_loss is 0.015230
# region loss is 0.006572405807673931, affinity loss is 0.010257736779749393
# Epoch is [1/20], mini-batch is [103/275], time consumption is 8.086856, batch_loss is 0.016830
# region loss is 0.009933936409652233, affinity loss is 0.01398430299013853
# Epoch is [1/20], mini-batch is [104/275], time consumption is 10.702730, batch_loss is 0.023918
# region loss is 0.013915644027292728, affinity loss is 0.017466150224208832
# Epoch is [1/20], mini-batch is [105/275], time consumption is 12.807738, batch_loss is 0.031382
# Tue May 23 01:59:10 2023
# region loss is 0.011549924500286579, affinity loss is 0.028655964881181717
# Epoch is [1/20], mini-batch is [106/275], time consumption is 9.395647, batch_loss is 0.040206
# region loss is 0.009485009126365185, affinity loss is 0.016461163759231567
# Epoch is [1/20], mini-batch is [107/275], time consumption is 9.339959, batch_loss is 0.025946
# region loss is 0.009595435112714767, affinity loss is 0.007442220579832792
# Epoch is [1/20], mini-batch is [108/275], time consumption is 10.073628, batch_loss is 0.017038
# region loss is 0.009213234297931194, affinity loss is 0.013033634051680565
# Epoch is [1/20], mini-batch is [109/275], time consumption is 10.483272, batch_loss is 0.022247
# region loss is 0.007915418595075607, affinity loss is 0.01478059496730566
# Epoch is [1/20], mini-batch is [110/275], time consumption is 10.087506, batch_loss is 0.022696
# Tue May 23 02:00:02 2023
# region loss is 0.008942157961428165, affinity loss is 0.009433668106794357
# Epoch is [1/20], mini-batch is [111/275], time consumption is 10.519080, batch_loss is 0.018376
# region loss is 0.008752739056944847, affinity loss is 0.011253876611590385
# Epoch is [1/20], mini-batch is [112/275], time consumption is 8.620406, batch_loss is 0.020007
# region loss is 0.008581782691180706, affinity loss is 0.015186899341642857
# Epoch is [1/20], mini-batch is [113/275], time consumption is 9.484338, batch_loss is 0.023769
# region loss is 0.009623021818697453, affinity loss is 0.012990966439247131
# Epoch is [1/20], mini-batch is [114/275], time consumption is 9.331129, batch_loss is 0.022614
# region loss is 0.009304890409111977, affinity loss is 0.011960201896727085
# Epoch is [1/20], mini-batch is [115/275], time consumption is 11.733632, batch_loss is 0.021265
# Tue May 23 02:00:54 2023
# region loss is 0.008912207558751106, affinity loss is 0.0124065475538373
# Epoch is [1/20], mini-batch is [116/275], time consumption is 9.151479, batch_loss is 0.021319
# region loss is 0.01676003262400627, affinity loss is 0.018616359680891037
# Epoch is [1/20], mini-batch is [117/275], time consumption is 9.021361, batch_loss is 0.035376
# region loss is 0.017991842702031136, affinity loss is 0.030183855444192886
# Epoch is [1/20], mini-batch is [118/275], time consumption is 10.597495, batch_loss is 0.048176
# region loss is 0.00793288554996252, affinity loss is 0.011707914993166924
# Epoch is [1/20], mini-batch is [119/275], time consumption is 9.319466, batch_loss is 0.019641
# region loss is 0.015647724270820618, affinity loss is 0.011270389892160892
# Epoch is [1/20], mini-batch is [120/275], time consumption is 10.186871, batch_loss is 0.026918
# Tue May 23 02:01:44 2023
# region loss is 0.008761603385210037, affinity loss is 0.01162117999047041
# Epoch is [1/20], mini-batch is [121/275], time consumption is 9.920113, batch_loss is 0.020383
# region loss is 0.008597065694630146, affinity loss is 0.019825322553515434
# Epoch is [1/20], mini-batch is [122/275], time consumption is 8.190665, batch_loss is 0.028422
# region loss is 0.008546922355890274, affinity loss is 0.0110278045758605
# Epoch is [1/20], mini-batch is [123/275], time consumption is 8.875033, batch_loss is 0.019575
# region loss is 0.016791362315416336, affinity loss is 0.018504586070775986
# Epoch is [1/20], mini-batch is [124/275], time consumption is 10.458298, batch_loss is 0.035296
# region loss is 0.00694531574845314, affinity loss is 0.013525393791496754
# Epoch is [1/20], mini-batch is [125/275], time consumption is 10.110188, batch_loss is 0.020471
# Tue May 23 02:02:34 2023
# region loss is 0.007380169816315174, affinity loss is 0.011570418253540993
# Epoch is [1/20], mini-batch is [126/275], time consumption is 11.648068, batch_loss is 0.018951
# region loss is 0.02331237867474556, affinity loss is 0.019672827795147896
# Epoch is [1/20], mini-batch is [127/275], time consumption is 8.612793, batch_loss is 0.042985
# region loss is 0.007939298637211323, affinity loss is 0.01136779598891735
# Epoch is [1/20], mini-batch is [128/275], time consumption is 8.191601, batch_loss is 0.019307
# region loss is 0.005866119172424078, affinity loss is 0.011876679956912994
# Epoch is [1/20], mini-batch is [129/275], time consumption is 9.348180, batch_loss is 0.017743
# region loss is 0.00872772466391325, affinity loss is 0.013540016487240791
# Epoch is [1/20], mini-batch is [130/275], time consumption is 9.412154, batch_loss is 0.022268
# Tue May 23 02:03:24 2023
# region loss is 0.0071404604241251945, affinity loss is 0.010432129725813866
# Epoch is [1/20], mini-batch is [131/275], time consumption is 10.346850, batch_loss is 0.017573
# region loss is 0.008683545514941216, affinity loss is 0.016574101522564888
# Epoch is [1/20], mini-batch is [132/275], time consumption is 8.870404, batch_loss is 0.025258
# region loss is 0.009274517185986042, affinity loss is 0.016594259068369865
# Epoch is [1/20], mini-batch is [133/275], time consumption is 9.633903, batch_loss is 0.025869
# region loss is 0.014844697900116444, affinity loss is 0.017360642552375793
# Epoch is [1/20], mini-batch is [134/275], time consumption is 9.609008, batch_loss is 0.032205
# region loss is 0.005089213140308857, affinity loss is 0.009096628054976463
# Epoch is [1/20], mini-batch is [135/275], time consumption is 8.829878, batch_loss is 0.014186
# Tue May 23 02:04:13 2023
# region loss is 0.009275163523852825, affinity loss is 0.015138023532927036
# Epoch is [1/20], mini-batch is [136/275], time consumption is 11.964199, batch_loss is 0.024413
# region loss is 0.0074272253550589085, affinity loss is 0.01300592627376318
# Epoch is [1/20], mini-batch is [137/275], time consumption is 10.815009, batch_loss is 0.020433
# region loss is 0.008149842731654644, affinity loss is 0.012435206212103367
# Epoch is [1/20], mini-batch is [138/275], time consumption is 10.528424, batch_loss is 0.020585
# region loss is 0.009636524133384228, affinity loss is 0.013081474229693413
# Epoch is [1/20], mini-batch is [139/275], time consumption is 9.323911, batch_loss is 0.022718
# region loss is 0.008288640528917313, affinity loss is 0.012418891303241253
# Epoch is [1/20], mini-batch is [140/275], time consumption is 11.238368, batch_loss is 0.020708
# Tue May 23 02:05:09 2023
# region loss is 0.010034517385065556, affinity loss is 0.011013356037437916
# Epoch is [1/20], mini-batch is [141/275], time consumption is 11.486392, batch_loss is 0.021048
# region loss is 0.009150601923465729, affinity loss is 0.014136862009763718
# Epoch is [1/20], mini-batch is [142/275], time consumption is 9.116639, batch_loss is 0.023287
# region loss is 0.006547087803483009, affinity loss is 0.01176562998443842
# Epoch is [1/20], mini-batch is [143/275], time consumption is 8.825937, batch_loss is 0.018313
# region loss is 0.010336723178625107, affinity loss is 0.018122797831892967
# Epoch is [1/20], mini-batch is [144/275], time consumption is 9.619336, batch_loss is 0.028460
# region loss is 0.01607978716492653, affinity loss is 0.012515000998973846
# Epoch is [1/20], mini-batch is [145/275], time consumption is 9.108182, batch_loss is 0.028595
# Tue May 23 02:05:59 2023
# region loss is 0.01155206561088562, affinity loss is 0.012852656655013561
# Epoch is [1/20], mini-batch is [146/275], time consumption is 10.269034, batch_loss is 0.024405
# region loss is 0.009070714004337788, affinity loss is 0.011077857576310635
# Epoch is [1/20], mini-batch is [147/275], time consumption is 10.616747, batch_loss is 0.020149
# region loss is 0.013622410595417023, affinity loss is 0.013211965560913086
# Epoch is [1/20], mini-batch is [148/275], time consumption is 9.040820, batch_loss is 0.026834
# region loss is 0.006538751535117626, affinity loss is 0.01542222686111927
# Epoch is [1/20], mini-batch is [149/275], time consumption is 9.273082, batch_loss is 0.021961
# region loss is 0.0112106679007411, affinity loss is 0.015154213644564152
# Epoch is [1/20], mini-batch is [150/275], time consumption is 10.677201, batch_loss is 0.026365
# Tue May 23 02:06:51 2023
# region loss is 0.01637345366179943, affinity loss is 0.03228899836540222
# Epoch is [1/20], mini-batch is [151/275], time consumption is 9.205010, batch_loss is 0.048662
# region loss is 0.013301864266395569, affinity loss is 0.011005557142198086
# Epoch is [1/20], mini-batch is [152/275], time consumption is 10.225140, batch_loss is 0.024307
# region loss is 0.008914202451705933, affinity loss is 0.01202031597495079
# Epoch is [1/20], mini-batch is [153/275], time consumption is 10.536011, batch_loss is 0.020935
# region loss is 0.007411962375044823, affinity loss is 0.015063957311213017
# Epoch is [1/20], mini-batch is [154/275], time consumption is 9.885590, batch_loss is 0.022476
# region loss is 0.00811851117759943, affinity loss is 0.013656905852258205
# Epoch is [1/20], mini-batch is [155/275], time consumption is 11.702157, batch_loss is 0.021775
# Tue May 23 02:07:45 2023
# region loss is 0.01051829569041729, affinity loss is 0.01558620948344469
# Epoch is [1/20], mini-batch is [156/275], time consumption is 9.362642, batch_loss is 0.026105
# region loss is 0.006975011900067329, affinity loss is 0.010513405315577984
# Epoch is [1/20], mini-batch is [157/275], time consumption is 11.281411, batch_loss is 0.017488
# region loss is 0.0074987164698541164, affinity loss is 0.009544542990624905
# Epoch is [1/20], mini-batch is [158/275], time consumption is 10.214134, batch_loss is 0.017043
# region loss is 0.008342009037733078, affinity loss is 0.02461736463010311
# Epoch is [1/20], mini-batch is [159/275], time consumption is 8.834912, batch_loss is 0.032959
# region loss is 0.018573720008134842, affinity loss is 0.02162935584783554
# Epoch is [1/20], mini-batch is [160/275], time consumption is 10.236301, batch_loss is 0.040203
# Tue May 23 02:08:37 2023
# region loss is 0.015670930966734886, affinity loss is 0.015397496521472931
# Epoch is [1/20], mini-batch is [161/275], time consumption is 11.105356, batch_loss is 0.031068
# region loss is 0.010428418405354023, affinity loss is 0.01925138756632805
# Epoch is [1/20], mini-batch is [162/275], time consumption is 10.108704, batch_loss is 0.029680
# region loss is 0.008769418112933636, affinity loss is 0.013597945682704449
# Epoch is [1/20], mini-batch is [163/275], time consumption is 8.527591, batch_loss is 0.022367
# region loss is 0.01034733559936285, affinity loss is 0.0154085922986269
# Epoch is [1/20], mini-batch is [164/275], time consumption is 9.505578, batch_loss is 0.025756
# region loss is 0.008442412130534649, affinity loss is 0.015100150369107723
# Epoch is [1/20], mini-batch is [165/275], time consumption is 9.551104, batch_loss is 0.023543
# Tue May 23 02:09:28 2023
# region loss is 0.011346651241183281, affinity loss is 0.017827672883868217
# Epoch is [1/20], mini-batch is [166/275], time consumption is 9.002229, batch_loss is 0.029174
# region loss is 0.007468280382454395, affinity loss is 0.009934820234775543
# Epoch is [1/20], mini-batch is [167/275], time consumption is 8.948336, batch_loss is 0.017403
# region loss is 0.011422691866755486, affinity loss is 0.01556288730353117
# Epoch is [1/20], mini-batch is [168/275], time consumption is 11.270227, batch_loss is 0.026986
# region loss is 0.0074415928684175014, affinity loss is 0.009881139732897282
# Epoch is [1/20], mini-batch is [169/275], time consumption is 9.422568, batch_loss is 0.017323
# region loss is 0.007437872234731913, affinity loss is 0.011590162292122841
# Epoch is [1/20], mini-batch is [170/275], time consumption is 10.851168, batch_loss is 0.019028
# Tue May 23 02:10:20 2023
# region loss is 0.0088519137352705, affinity loss is 0.009264515712857246
# Epoch is [1/20], mini-batch is [171/275], time consumption is 9.857226, batch_loss is 0.018116
# region loss is 0.007191781885921955, affinity loss is 0.015011420473456383
# Epoch is [1/20], mini-batch is [172/275], time consumption is 7.941932, batch_loss is 0.022203
# region loss is 0.005540994927287102, affinity loss is 0.009685655124485493
# Epoch is [1/20], mini-batch is [173/275], time consumption is 11.166286, batch_loss is 0.015227
# region loss is 0.007725961972028017, affinity loss is 0.01113737840205431
# Epoch is [1/20], mini-batch is [174/275], time consumption is 11.218069, batch_loss is 0.018863
# region loss is 0.013439573347568512, affinity loss is 0.014919979497790337
# Epoch is [1/20], mini-batch is [175/275], time consumption is 11.297753, batch_loss is 0.028360
# Tue May 23 02:11:14 2023
# region loss is 0.009194784797728062, affinity loss is 0.012415741570293903
# Epoch is [1/20], mini-batch is [176/275], time consumption is 9.028701, batch_loss is 0.021611
# region loss is 0.00690548587590456, affinity loss is 0.009579832665622234
# Epoch is [1/20], mini-batch is [177/275], time consumption is 10.457500, batch_loss is 0.016485
# region loss is 0.010835487395524979, affinity loss is 0.01826806366443634
# Epoch is [1/20], mini-batch is [178/275], time consumption is 9.132801, batch_loss is 0.029104
# region loss is 0.006701226346194744, affinity loss is 0.010005593299865723
# Epoch is [1/20], mini-batch is [179/275], time consumption is 9.385064, batch_loss is 0.016707
# region loss is 0.01050398126244545, affinity loss is 0.012262314558029175
# Epoch is [1/20], mini-batch is [180/275], time consumption is 10.287948, batch_loss is 0.022766
# Tue May 23 02:12:04 2023
# region loss is 0.006824682001024485, affinity loss is 0.010599970817565918
# Epoch is [1/20], mini-batch is [181/275], time consumption is 9.125805, batch_loss is 0.017425
# region loss is 0.009317055344581604, affinity loss is 0.013042625971138477
# Epoch is [1/20], mini-batch is [182/275], time consumption is 11.128097, batch_loss is 0.022360
# region loss is 0.007484716828912497, affinity loss is 0.01424091774970293
# Epoch is [1/20], mini-batch is [183/275], time consumption is 9.841210, batch_loss is 0.021726
# region loss is 0.014408238232135773, affinity loss is 0.013908686116337776
# Epoch is [1/20], mini-batch is [184/275], time consumption is 10.244593, batch_loss is 0.028317
# region loss is 0.012719026766717434, affinity loss is 0.03280063718557358
# Epoch is [1/20], mini-batch is [185/275], time consumption is 9.748305, batch_loss is 0.045520
# Tue May 23 02:12:57 2023
# region loss is 0.006334774196147919, affinity loss is 0.007630320731550455
# Epoch is [1/20], mini-batch is [186/275], time consumption is 9.386015, batch_loss is 0.013965
# region loss is 0.007628780324012041, affinity loss is 0.015419849194586277
# Epoch is [1/20], mini-batch is [187/275], time consumption is 12.686460, batch_loss is 0.023049
# region loss is 0.008554709143936634, affinity loss is 0.010295870713889599
# Epoch is [1/20], mini-batch is [188/275], time consumption is 10.594562, batch_loss is 0.018851
# region loss is 0.01784512586891651, affinity loss is 0.015649138018488884
# Epoch is [1/20], mini-batch is [189/275], time consumption is 8.363575, batch_loss is 0.033494
# region loss is 0.009630054235458374, affinity loss is 0.015904756262898445
# Epoch is [1/20], mini-batch is [190/275], time consumption is 10.376740, batch_loss is 0.025535
# Tue May 23 02:13:50 2023
# region loss is 0.00778570119291544, affinity loss is 0.011733569204807281
# Epoch is [1/20], mini-batch is [191/275], time consumption is 9.366443, batch_loss is 0.019519
# region loss is 0.007589820772409439, affinity loss is 0.020279861986637115
# Epoch is [1/20], mini-batch is [192/275], time consumption is 8.953867, batch_loss is 0.027870
# region loss is 0.008161923848092556, affinity loss is 0.01033580768853426
# Epoch is [1/20], mini-batch is [193/275], time consumption is 8.750313, batch_loss is 0.018498
# region loss is 0.006854645442217588, affinity loss is 0.011586259119212627
# Epoch is [1/20], mini-batch is [194/275], time consumption is 11.173674, batch_loss is 0.018441
# region loss is 0.014592236839234829, affinity loss is 0.017094913870096207
# Epoch is [1/20], mini-batch is [195/275], time consumption is 10.488419, batch_loss is 0.031687
# Tue May 23 02:14:41 2023
# region loss is 0.009861870668828487, affinity loss is 0.013777147978544235
# Epoch is [1/20], mini-batch is [196/275], time consumption is 11.297038, batch_loss is 0.023639
# region loss is 0.009803605265915394, affinity loss is 0.01452729757875204
# Epoch is [1/20], mini-batch is [197/275], time consumption is 10.663086, batch_loss is 0.024331
# region loss is 0.01794581115245819, affinity loss is 0.025930257514119148
# Epoch is [1/20], mini-batch is [198/275], time consumption is 8.996534, batch_loss is 0.043876
# region loss is 0.011168163269758224, affinity loss is 0.018333133310079575
# Epoch is [1/20], mini-batch is [199/275], time consumption is 9.389988, batch_loss is 0.029501
# region loss is 0.014952389523386955, affinity loss is 0.02318999357521534
# Epoch is [1/20], mini-batch is [200/275], time consumption is 10.172988, batch_loss is 0.038142
# Tue May 23 02:15:34 2023
# region loss is 0.006108321715146303, affinity loss is 0.010338126681745052
# Epoch is [1/20], mini-batch is [201/275], time consumption is 11.727290, batch_loss is 0.016446
# region loss is 0.006869075819849968, affinity loss is 0.01222290564328432
# Epoch is [1/20], mini-batch is [202/275], time consumption is 8.668492, batch_loss is 0.019092
# region loss is 0.00993714015930891, affinity loss is 0.012263589538633823
# Epoch is [1/20], mini-batch is [203/275], time consumption is 9.281111, batch_loss is 0.022201
# region loss is 0.005573686212301254, affinity loss is 0.0105876000598073
# Epoch is [1/20], mini-batch is [204/275], time consumption is 9.471975, batch_loss is 0.016161
# region loss is 0.006657624617218971, affinity loss is 0.011267373338341713
# Epoch is [1/20], mini-batch is [205/275], time consumption is 8.729507, batch_loss is 0.017925
# Tue May 23 02:16:24 2023
# region loss is 0.006498085334897041, affinity loss is 0.007526205852627754
# Epoch is [1/20], mini-batch is [206/275], time consumption is 10.821929, batch_loss is 0.014024
# region loss is 0.005963258910924196, affinity loss is 0.010436254553496838
# Epoch is [1/20], mini-batch is [207/275], time consumption is 10.924074, batch_loss is 0.016400
# region loss is 0.006813101936131716, affinity loss is 0.011907518841326237
# Epoch is [1/20], mini-batch is [208/275], time consumption is 9.445976, batch_loss is 0.018721
# region loss is 0.010370091535151005, affinity loss is 0.019416458904743195
# Epoch is [1/20], mini-batch is [209/275], time consumption is 9.401754, batch_loss is 0.029787
# region loss is 0.026455581188201904, affinity loss is 0.017004312947392464
# Epoch is [1/20], mini-batch is [210/275], time consumption is 11.203554, batch_loss is 0.043460
# Tue May 23 02:17:18 2023
# region loss is 0.006278722081333399, affinity loss is 0.013132535852491856
# Epoch is [1/20], mini-batch is [211/275], time consumption is 11.469891, batch_loss is 0.019411
# region loss is 0.01687593199312687, affinity loss is 0.018864981830120087
# Epoch is [1/20], mini-batch is [212/275], time consumption is 8.831214, batch_loss is 0.035741
# region loss is 0.006787657737731934, affinity loss is 0.012179149314761162
# Epoch is [1/20], mini-batch is [213/275], time consumption is 11.224173, batch_loss is 0.018967
# region loss is 0.010859306901693344, affinity loss is 0.014554832130670547
# Epoch is [1/20], mini-batch is [214/275], time consumption is 9.189472, batch_loss is 0.025414
# region loss is 0.015633413568139076, affinity loss is 0.01923609897494316
# Epoch is [1/20], mini-batch is [215/275], time consumption is 10.819058, batch_loss is 0.034870
# Tue May 23 02:18:12 2023
# region loss is 0.008733419701457024, affinity loss is 0.012283251620829105
# Epoch is [1/20], mini-batch is [216/275], time consumption is 9.775496, batch_loss is 0.021017
# region loss is 0.008752730675041676, affinity loss is 0.01167154498398304
# Epoch is [1/20], mini-batch is [217/275], time consumption is 10.056818, batch_loss is 0.020424
# region loss is 0.00885402038693428, affinity loss is 0.0208108052611351
# Epoch is [1/20], mini-batch is [218/275], time consumption is 10.621161, batch_loss is 0.029665
# region loss is 0.01573815755546093, affinity loss is 0.011795753613114357
# Epoch is [1/20], mini-batch is [219/275], time consumption is 10.709462, batch_loss is 0.027534
# region loss is 0.022053005173802376, affinity loss is 0.023355180397629738
# Epoch is [1/20], mini-batch is [220/275], time consumption is 9.666558, batch_loss is 0.045408
# Tue May 23 02:19:04 2023
# region loss is 0.005812899209558964, affinity loss is 0.013189850375056267
# Epoch is [1/20], mini-batch is [221/275], time consumption is 10.145521, batch_loss is 0.019003
# region loss is 0.005907528568059206, affinity loss is 0.009456612169742584
# Epoch is [1/20], mini-batch is [222/275], time consumption is 10.604749, batch_loss is 0.015364
# region loss is 0.008122636936604977, affinity loss is 0.011853320524096489
# Epoch is [1/20], mini-batch is [223/275], time consumption is 8.621832, batch_loss is 0.019976
# region loss is 0.011967979371547699, affinity loss is 0.01637810654938221
# Epoch is [1/20], mini-batch is [224/275], time consumption is 9.725034, batch_loss is 0.028346
# region loss is 0.009916684590280056, affinity loss is 0.013437626883387566
# Epoch is [1/20], mini-batch is [225/275], time consumption is 10.130467, batch_loss is 0.023354
# Tue May 23 02:19:56 2023
# region loss is 0.009454866871237755, affinity loss is 0.02119126357138157
# Epoch is [1/20], mini-batch is [226/275], time consumption is 9.424971, batch_loss is 0.030646
# region loss is 0.011414551176130772, affinity loss is 0.01125203724950552
# Epoch is [1/20], mini-batch is [227/275], time consumption is 9.604952, batch_loss is 0.022667
# region loss is 0.00671381363645196, affinity loss is 0.01637483388185501
# Epoch is [1/20], mini-batch is [228/275], time consumption is 8.619044, batch_loss is 0.023089
# region loss is 0.007777437102049589, affinity loss is 0.011368135921657085
# Epoch is [1/20], mini-batch is [229/275], time consumption is 9.491693, batch_loss is 0.019146
# region loss is 0.008788231760263443, affinity loss is 0.013329027220606804
# Epoch is [1/20], mini-batch is [230/275], time consumption is 8.487637, batch_loss is 0.022117
# Tue May 23 02:20:44 2023
# region loss is 0.01158506516367197, affinity loss is 0.01384924165904522
# Epoch is [1/20], mini-batch is [231/275], time consumption is 9.336487, batch_loss is 0.025434
# region loss is 0.010873504914343357, affinity loss is 0.013880876824259758
# Epoch is [1/20], mini-batch is [232/275], time consumption is 9.046483, batch_loss is 0.024754
# region loss is 0.012979778461158276, affinity loss is 0.014823907986283302
# Epoch is [1/20], mini-batch is [233/275], time consumption is 8.453361, batch_loss is 0.027804
# region loss is 0.008374863304197788, affinity loss is 0.012892358936369419
# Epoch is [1/20], mini-batch is [234/275], time consumption is 8.670524, batch_loss is 0.021267
# region loss is 0.012396624311804771, affinity loss is 0.012083766050636768
# Epoch is [1/20], mini-batch is [235/275], time consumption is 9.667027, batch_loss is 0.024480
# Tue May 23 02:21:31 2023
# region loss is 0.008813958615064621, affinity loss is 0.029757481068372726
# Epoch is [1/20], mini-batch is [236/275], time consumption is 10.681378, batch_loss is 0.038571
# region loss is 0.011469628661870956, affinity loss is 0.015952708199620247
# Epoch is [1/20], mini-batch is [237/275], time consumption is 11.051188, batch_loss is 0.027422
# region loss is 0.016425717622041702, affinity loss is 0.017536435276269913
# Epoch is [1/20], mini-batch is [238/275], time consumption is 12.370053, batch_loss is 0.033962
# region loss is 0.0073759048245847225, affinity loss is 0.0175867211073637
# Epoch is [1/20], mini-batch is [239/275], time consumption is 10.101876, batch_loss is 0.024963
# region loss is 0.010166694410145283, affinity loss is 0.016466062515974045
# Epoch is [1/20], mini-batch is [240/275], time consumption is 11.081526, batch_loss is 0.026633
# Tue May 23 02:22:29 2023
# region loss is 0.006047090049833059, affinity loss is 0.01147729903459549
# Epoch is [1/20], mini-batch is [241/275], time consumption is 9.748362, batch_loss is 0.017524
# region loss is 0.008240627124905586, affinity loss is 0.01679919846355915
# Epoch is [1/20], mini-batch is [242/275], time consumption is 9.465498, batch_loss is 0.025040
# region loss is 0.033579275012016296, affinity loss is 0.02673175558447838
# Epoch is [1/20], mini-batch is [243/275], time consumption is 8.675628, batch_loss is 0.060311
# region loss is 0.017253616824746132, affinity loss is 0.021450454369187355
# Epoch is [1/20], mini-batch is [244/275], time consumption is 9.079158, batch_loss is 0.038704
# region loss is 0.011148662306368351, affinity loss is 0.016371991485357285
# Epoch is [1/20], mini-batch is [245/275], time consumption is 9.458571, batch_loss is 0.027521
# Tue May 23 02:23:17 2023
# region loss is 0.00753096304833889, affinity loss is 0.011356819421052933
# Epoch is [1/20], mini-batch is [246/275], time consumption is 9.934027, batch_loss is 0.018888
# region loss is 0.009524271823465824, affinity loss is 0.015153163112699986
# Epoch is [1/20], mini-batch is [247/275], time consumption is 9.106665, batch_loss is 0.024677
# region loss is 0.010400147177278996, affinity loss is 0.013862290419638157
# Epoch is [1/20], mini-batch is [248/275], time consumption is 9.106661, batch_loss is 0.024262
# region loss is 0.008852328173816204, affinity loss is 0.012743474915623665
# Epoch is [1/20], mini-batch is [249/275], time consumption is 11.385525, batch_loss is 0.021596
# region loss is 0.0071589830331504345, affinity loss is 0.016782278195023537
# Epoch is [1/20], mini-batch is [250/275], time consumption is 8.421367, batch_loss is 0.023941
# Tue May 23 02:24:07 2023
# region loss is 0.005655894987285137, affinity loss is 0.010065107606351376
# Epoch is [1/20], mini-batch is [251/275], time consumption is 9.394621, batch_loss is 0.015721
# region loss is 0.008766916580498219, affinity loss is 0.011465824209153652
# Epoch is [1/20], mini-batch is [252/275], time consumption is 10.121810, batch_loss is 0.020233
# region loss is 0.007710672914981842, affinity loss is 0.012019910849630833
# Epoch is [1/20], mini-batch is [253/275], time consumption is 9.697218, batch_loss is 0.019731
# region loss is 0.0083379615098238, affinity loss is 0.016257314011454582
# Epoch is [1/20], mini-batch is [254/275], time consumption is 9.306553, batch_loss is 0.024595
# region loss is 0.006766319740563631, affinity loss is 0.010197351686656475
# Epoch is [1/20], mini-batch is [255/275], time consumption is 9.347395, batch_loss is 0.016964
# Tue May 23 02:24:57 2023
# region loss is 0.01687014289200306, affinity loss is 0.04791906103491783
# Epoch is [1/20], mini-batch is [256/275], time consumption is 11.464723, batch_loss is 0.064789
# region loss is 0.006155581213533878, affinity loss is 0.01095588505268097
# Epoch is [1/20], mini-batch is [257/275], time consumption is 8.295101, batch_loss is 0.017111
# region loss is 0.009505138732492924, affinity loss is 0.013718555681407452
# Epoch is [1/20], mini-batch is [258/275], time consumption is 9.260111, batch_loss is 0.023224
# region loss is 0.0077744582667946815, affinity loss is 0.01599537953734398
# Epoch is [1/20], mini-batch is [259/275], time consumption is 8.843800, batch_loss is 0.023770
# region loss is 0.006858280394226313, affinity loss is 0.014291135594248772
# Epoch is [1/20], mini-batch is [260/275], time consumption is 9.487343, batch_loss is 0.021149
# Tue May 23 02:25:47 2023
# region loss is 0.007462067063897848, affinity loss is 0.012240054085850716
# Epoch is [1/20], mini-batch is [261/275], time consumption is 10.931614, batch_loss is 0.019702
# region loss is 0.00892778392881155, affinity loss is 0.0169596578925848
# Epoch is [1/20], mini-batch is [262/275], time consumption is 8.794940, batch_loss is 0.025887
# region loss is 0.010154560208320618, affinity loss is 0.017287727445364
# Epoch is [1/20], mini-batch is [263/275], time consumption is 9.121506, batch_loss is 0.027442
# region loss is 0.006086321547627449, affinity loss is 0.014483949169516563
# Epoch is [1/20], mini-batch is [264/275], time consumption is 13.332047, batch_loss is 0.020570
# region loss is 0.016073154285550117, affinity loss is 0.014846514910459518
# Epoch is [1/20], mini-batch is [265/275], time consumption is 9.055862, batch_loss is 0.030920
# Tue May 23 02:26:40 2023
# region loss is 0.013059566728770733, affinity loss is 0.01698870025575161
# Epoch is [1/20], mini-batch is [266/275], time consumption is 11.081455, batch_loss is 0.030048
# region loss is 0.012866650708019733, affinity loss is 0.018116088584065437
# Epoch is [1/20], mini-batch is [267/275], time consumption is 9.058160, batch_loss is 0.030983
# region loss is 0.025206292048096657, affinity loss is 0.026855342090129852
# Epoch is [1/20], mini-batch is [268/275], time consumption is 10.373517, batch_loss is 0.052062
# region loss is 0.019455082714557648, affinity loss is 0.017561908811330795
# Epoch is [1/20], mini-batch is [269/275], time consumption is 9.344497, batch_loss is 0.037017
# region loss is 0.008236193098127842, affinity loss is 0.013194885104894638
# Epoch is [1/20], mini-batch is [270/275], time consumption is 9.397337, batch_loss is 0.021431
# Tue May 23 02:27:32 2023
# region loss is 0.007710116915404797, affinity loss is 0.013392554596066475
# Epoch is [1/20], mini-batch is [271/275], time consumption is 11.411908, batch_loss is 0.021103
# region loss is 0.00626480532810092, affinity loss is 0.010430922731757164
# Epoch is [1/20], mini-batch is [272/275], time consumption is 9.479379, batch_loss is 0.016696
# region loss is 0.009042496792972088, affinity loss is 0.012867345474660397
# Epoch is [1/20], mini-batch is [273/275], time consumption is 8.916427, batch_loss is 0.021910
# region loss is 0.012922199442982674, affinity loss is 0.01780914142727852
# Epoch is [1/20], mini-batch is [274/275], time consumption is 9.588552, batch_loss is 0.030731
# region loss is 0.006643449421972036, affinity loss is 0.011145955882966518
# ...
# region loss is 0.010577037930488586, affinity loss is 0.010005657561123371
# Epoch is [8/20], mini-batch is [160/275], time consumption is 2.929555, batch_loss is 0.020583
# Tue May 23 04:52:22 2023
# region loss is 0.01012578047811985, affinity loss is 0.009855112060904503
# Epoch is [8/20], mini-batch is [161/275], time consumption is 3.068492, batch_loss is 0.019981
# region loss is 0.0032462477684020996, affinity loss is 0.004363781772553921
# Epoch is [8/20], mini-batch is [162/275], time consumption is 4.443400, batch_loss is 0.007610
# region loss is 0.004876328632235527, affinity loss is 0.006745254620909691
# Epoch is [8/20], mini-batch is [163/275], time consumption is 5.928843, batch_loss is 0.011622
# region loss is 0.006033309269696474, affinity loss is 0.01122064609080553
# Epoch is [8/20], mini-batch is [164/275], time consumption is 3.336065, batch_loss is 0.017254
# region loss is 0.010907871648669243, affinity loss is 0.013363862410187721
# Epoch is [8/20], mini-batch is [165/275], time consumption is 4.248349, batch_loss is 0.024272
# Tue May 23 04:52:45 2023
# region loss is 0.006940112449228764, affinity loss is 0.008833955973386765
# Epoch is [8/20], mini-batch is [166/275], time consumption is 4.842582, batch_loss is 0.015774
# region loss is 0.006116021424531937, affinity loss is 0.009241927415132523
# Epoch is [8/20], mini-batch is [167/275], time consumption is 4.126043, batch_loss is 0.015358
# region loss is 0.006183928810060024, affinity loss is 0.011303761973977089
# Epoch is [8/20], mini-batch is [168/275], time consumption is 5.176397, batch_loss is 0.017488
# region loss is 0.013508913107216358, affinity loss is 0.014655480161309242
# Epoch is [8/20], mini-batch is [169/275], time consumption is 4.138846, batch_loss is 0.028164
# region loss is 0.014476651325821877, affinity loss is 0.01591273956000805
# Epoch is [8/20], mini-batch is [170/275], time consumption is 5.134766, batch_loss is 0.030389
# Tue May 23 04:53:10 2023
# region loss is 0.010881549678742886, affinity loss is 0.012422594241797924
# Epoch is [8/20], mini-batch is [171/275], time consumption is 4.736193, batch_loss is 0.023304
# region loss is 0.005323316901922226, affinity loss is 0.015836432576179504
# Epoch is [8/20], mini-batch is [172/275], time consumption is 3.669775, batch_loss is 0.021160
# region loss is 0.01183075550943613, affinity loss is 0.01378608774393797
# Epoch is [8/20], mini-batch is [173/275], time consumption is 3.428788, batch_loss is 0.025617
# region loss is 0.0068093216978013515, affinity loss is 0.013467947021126747
# Epoch is [8/20], mini-batch is [174/275], time consumption is 3.428771, batch_loss is 0.020277
# region loss is 0.018625136464834213, affinity loss is 0.02927730232477188
# Epoch is [8/20], mini-batch is [175/275], time consumption is 6.286695, batch_loss is 0.047902
# Tue May 23 04:53:34 2023
# region loss is 0.006179335061460733, affinity loss is 0.01220313273370266
# Epoch is [8/20], mini-batch is [176/275], time consumption is 3.609869, batch_loss is 0.018382
# region loss is 0.006194150075316429, affinity loss is 0.014013097621500492
# Epoch is [8/20], mini-batch is [177/275], time consumption is 3.910434, batch_loss is 0.020207
# region loss is 0.012250001542270184, affinity loss is 0.014263301156461239
# Epoch is [8/20], mini-batch is [178/275], time consumption is 5.483853, batch_loss is 0.026513
# region loss is 0.004836848005652428, affinity loss is 0.009960795752704144
# Epoch is [8/20], mini-batch is [179/275], time consumption is 2.729536, batch_loss is 0.014798
# region loss is 0.008818068541586399, affinity loss is 0.008776197209954262
# Epoch is [8/20], mini-batch is [180/275], time consumption is 5.057555, batch_loss is 0.017594
# Tue May 23 04:53:57 2023
# region loss is 0.009218896739184856, affinity loss is 0.015345382504165173
# Epoch is [8/20], mini-batch is [181/275], time consumption is 4.954752, batch_loss is 0.024564
# region loss is 0.0063792988657951355, affinity loss is 0.008196267299354076
# Epoch is [8/20], mini-batch is [182/275], time consumption is 4.199602, batch_loss is 0.014576
# region loss is 0.00907648354768753, affinity loss is 0.012997743673622608
# Epoch is [8/20], mini-batch is [183/275], time consumption is 3.218774, batch_loss is 0.022074
# region loss is 0.005687653087079525, affinity loss is 0.013348009437322617
# Epoch is [8/20], mini-batch is [184/275], time consumption is 4.488467, batch_loss is 0.019036
# region loss is 0.005419090855866671, affinity loss is 0.01052872184664011
# Epoch is [8/20], mini-batch is [185/275], time consumption is 3.391551, batch_loss is 0.015948
# Tue May 23 04:54:20 2023
# region loss is 0.00481803435832262, affinity loss is 0.006700362078845501
# Epoch is [8/20], mini-batch is [186/275], time consumption is 4.586307, batch_loss is 0.011518
# region loss is 0.010582463815808296, affinity loss is 0.00885933917015791
# Epoch is [8/20], mini-batch is [187/275], time consumption is 4.456833, batch_loss is 0.019442
# region loss is 0.00613695103675127, affinity loss is 0.010607089847326279
# Epoch is [8/20], mini-batch is [188/275], time consumption is 3.673260, batch_loss is 0.016744
# region loss is 0.016301749274134636, affinity loss is 0.011734371073544025
# Epoch is [8/20], mini-batch is [189/275], time consumption is 3.482487, batch_loss is 0.028036
# region loss is 0.007581137586385012, affinity loss is 0.0141622144728899
# Epoch is [8/20], mini-batch is [190/275], time consumption is 5.247754, batch_loss is 0.021743
# Tue May 23 04:54:43 2023
# region loss is 0.004882446955889463, affinity loss is 0.009822188876569271
# Epoch is [8/20], mini-batch is [191/275], time consumption is 4.179772, batch_loss is 0.014705
# region loss is 0.005350891500711441, affinity loss is 0.008466758765280247
# Epoch is [8/20], mini-batch is [192/275], time consumption is 5.076193, batch_loss is 0.013818
# region loss is 0.00981413759291172, affinity loss is 0.011040334589779377
# Epoch is [8/20], mini-batch is [193/275], time consumption is 4.812908, batch_loss is 0.020854
# region loss is 0.015963571146130562, affinity loss is 0.020663997158408165
# Epoch is [8/20], mini-batch is [194/275], time consumption is 5.277622, batch_loss is 0.036628
# region loss is 0.007173934020102024, affinity loss is 0.014407943934202194
# Epoch is [8/20], mini-batch is [195/275], time consumption is 3.798104, batch_loss is 0.021582
# Tue May 23 04:55:09 2023
# region loss is 0.008537539280951023, affinity loss is 0.010656248778104782
# Epoch is [8/20], mini-batch is [196/275], time consumption is 4.427619, batch_loss is 0.019194
# region loss is 0.0062947398982942104, affinity loss is 0.009085978381335735
# Epoch is [8/20], mini-batch is [197/275], time consumption is 2.886843, batch_loss is 0.015381
# region loss is 0.006137985270470381, affinity loss is 0.014140203595161438
# Epoch is [8/20], mini-batch is [198/275], time consumption is 4.377713, batch_loss is 0.020278
# region loss is 0.006561442743986845, affinity loss is 0.01632244512438774
# Epoch is [8/20], mini-batch is [199/275], time consumption is 3.672211, batch_loss is 0.022884
# region loss is 0.00737485708668828, affinity loss is 0.007840248756110668
# Epoch is [8/20], mini-batch is [200/275], time consumption is 3.460392, batch_loss is 0.015215
# Tue May 23 04:55:30 2023
# region loss is 0.007144976872950792, affinity loss is 0.011759914457798004
# Epoch is [8/20], mini-batch is [201/275], time consumption is 5.797504, batch_loss is 0.018905
# region loss is 0.005795114208012819, affinity loss is 0.011999168433248997
# Epoch is [8/20], mini-batch is [202/275], time consumption is 3.964989, batch_loss is 0.017794
# region loss is 0.0068648080341517925, affinity loss is 0.014712628908455372
# Epoch is [8/20], mini-batch is [203/275], time consumption is 4.098126, batch_loss is 0.021577
# region loss is 0.014585277996957302, affinity loss is 0.014914925210177898
# Epoch is [8/20], mini-batch is [204/275], time consumption is 2.967097, batch_loss is 0.029500
# region loss is 0.005925298202782869, affinity loss is 0.0067200628109276295
# Epoch is [8/20], mini-batch is [205/275], time consumption is 2.667737, batch_loss is 0.012645
# Tue May 23 04:55:51 2023
# region loss is 0.006222347263246775, affinity loss is 0.010848255828022957
# Epoch is [8/20], mini-batch is [206/275], time consumption is 5.191375, batch_loss is 0.017071
# region loss is 0.011683396063745022, affinity loss is 0.01112833060324192
# Epoch is [8/20], mini-batch is [207/275], time consumption is 2.618462, batch_loss is 0.022812
# region loss is 0.008607311174273491, affinity loss is 0.009921195916831493
# Epoch is [8/20], mini-batch is [208/275], time consumption is 4.647237, batch_loss is 0.018529
# region loss is 0.004820059519261122, affinity loss is 0.007195805199444294
# Epoch is [8/20], mini-batch is [209/275], time consumption is 6.289191, batch_loss is 0.012016
# region loss is 0.008062710054218769, affinity loss is 0.019425030797719955
# Epoch is [8/20], mini-batch is [210/275], time consumption is 2.690670, batch_loss is 0.027488
# Tue May 23 04:56:15 2023
# region loss is 0.008976547047495842, affinity loss is 0.010034354403614998
# Epoch is [8/20], mini-batch is [211/275], time consumption is 2.905531, batch_loss is 0.019011
# region loss is 0.005817601457238197, affinity loss is 0.012700175866484642
# Epoch is [8/20], mini-batch is [212/275], time consumption is 4.725854, batch_loss is 0.018518
# region loss is 0.0038878056220710278, affinity loss is 0.008109616115689278
# Epoch is [8/20], mini-batch is [213/275], time consumption is 4.156191, batch_loss is 0.011997
# region loss is 0.009312121197581291, affinity loss is 0.01073850691318512
# Epoch is [8/20], mini-batch is [214/275], time consumption is 4.358701, batch_loss is 0.020051
# region loss is 0.006502259522676468, affinity loss is 0.008398330770432949
# Epoch is [8/20], mini-batch is [215/275], time consumption is 5.765417, batch_loss is 0.014901
# Tue May 23 04:56:39 2023
# region loss is 0.009264806285500526, affinity loss is 0.01371705811470747
# Epoch is [8/20], mini-batch is [216/275], time consumption is 3.186820, batch_loss is 0.022982
# region loss is 0.0066115977242589, affinity loss is 0.009095385670661926
# Epoch is [8/20], mini-batch is [217/275], time consumption is 6.583950, batch_loss is 0.015707
# region loss is 0.010267681442201138, affinity loss is 0.016431899741292
# Epoch is [8/20], mini-batch is [218/275], time consumption is 4.229074, batch_loss is 0.026700
# region loss is 0.01157519593834877, affinity loss is 0.015873748809099197
# Epoch is [8/20], mini-batch is [219/275], time consumption is 3.526857, batch_loss is 0.027449
# region loss is 0.011251498013734818, affinity loss is 0.015436697751283646
# Epoch is [8/20], mini-batch is [220/275], time consumption is 2.550871, batch_loss is 0.026688
# Tue May 23 04:57:01 2023
# region loss is 0.004809069447219372, affinity loss is 0.010821488685905933
# Epoch is [8/20], mini-batch is [221/275], time consumption is 4.821769, batch_loss is 0.015631
# region loss is 0.009684856049716473, affinity loss is 0.009788447059690952
# Epoch is [8/20], mini-batch is [222/275], time consumption is 4.813206, batch_loss is 0.019473
# region loss is 0.00532040698453784, affinity loss is 0.009382459335029125
# Epoch is [8/20], mini-batch is [223/275], time consumption is 4.121785, batch_loss is 0.014703
# region loss is 0.005626677069813013, affinity loss is 0.007106601260602474
# Epoch is [8/20], mini-batch is [224/275], time consumption is 3.495854, batch_loss is 0.012733
# region loss is 0.011676661670207977, affinity loss is 0.01479047816246748
# Epoch is [8/20], mini-batch is [225/275], time consumption is 3.325008, batch_loss is 0.026467
# Tue May 23 04:57:24 2023
# region loss is 0.007575350347906351, affinity loss is 0.009639957919716835
# Epoch is [8/20], mini-batch is [226/275], time consumption is 6.288327, batch_loss is 0.017215
# region loss is 0.009485413320362568, affinity loss is 0.01432816032320261
# Epoch is [8/20], mini-batch is [227/275], time consumption is 5.843003, batch_loss is 0.023814
# region loss is 0.007408003322780132, affinity loss is 0.01250692829489708
# Epoch is [8/20], mini-batch is [228/275], time consumption is 6.589249, batch_loss is 0.019915
# region loss is 0.0061485543847084045, affinity loss is 0.009336992166936398
# Epoch is [8/20], mini-batch is [229/275], time consumption is 7.195069, batch_loss is 0.015486
# region loss is 0.006945708766579628, affinity loss is 0.012363641522824764
# Epoch is [8/20], mini-batch is [230/275], time consumption is 7.354100, batch_loss is 0.019309
# Tue May 23 04:57:59 2023
# region loss is 0.008568978868424892, affinity loss is 0.008779238909482956
# Epoch is [8/20], mini-batch is [231/275], time consumption is 6.265886, batch_loss is 0.017348
# region loss is 0.005386854987591505, affinity loss is 0.008904658257961273
# Epoch is [8/20], mini-batch is [232/275], time consumption is 5.237301, batch_loss is 0.014292
# region loss is 0.005526080261915922, affinity loss is 0.009891495108604431
# Epoch is [8/20], mini-batch is [233/275], time consumption is 5.316902, batch_loss is 0.015418
# region loss is 0.005128795746713877, affinity loss is 0.0074803330935537815
# Epoch is [8/20], mini-batch is [234/275], time consumption is 5.053149, batch_loss is 0.012609
# region loss is 0.011113002896308899, affinity loss is 0.014484728686511517
# Epoch is [8/20], mini-batch is [235/275], time consumption is 4.605788, batch_loss is 0.025598
# Tue May 23 04:58:28 2023
# region loss is 0.0070704747922718525, affinity loss is 0.01121237687766552
# Epoch is [8/20], mini-batch is [236/275], time consumption is 5.866908, batch_loss is 0.018283
# region loss is 0.0071156881749629974, affinity loss is 0.013887306675314903
# Epoch is [8/20], mini-batch is [237/275], time consumption is 3.235789, batch_loss is 0.021003
# region loss is 0.01308469194918871, affinity loss is 0.017877861857414246
# Epoch is [8/20], mini-batch is [238/275], time consumption is 3.806459, batch_loss is 0.030963
# region loss is 0.008222503587603569, affinity loss is 0.01450958289206028
# Epoch is [8/20], mini-batch is [239/275], time consumption is 4.222353, batch_loss is 0.022732
# region loss is 0.006915240548551083, affinity loss is 0.011038708500564098
# Epoch is [8/20], mini-batch is [240/275], time consumption is 4.534376, batch_loss is 0.017954
# Tue May 23 04:58:52 2023
# region loss is 0.007978701964020729, affinity loss is 0.018165219575166702
# Epoch is [8/20], mini-batch is [241/275], time consumption is 4.226025, batch_loss is 0.026144
# region loss is 0.007596335373818874, affinity loss is 0.010951545089483261
# Epoch is [8/20], mini-batch is [242/275], time consumption is 3.098977, batch_loss is 0.018548
# region loss is 0.005106088239699602, affinity loss is 0.0075268736109137535
# Epoch is [8/20], mini-batch is [243/275], time consumption is 3.860455, batch_loss is 0.012633
# region loss is 0.010272524319589138, affinity loss is 0.009008984081447124
# Epoch is [8/20], mini-batch is [244/275], time consumption is 4.708788, batch_loss is 0.019282
# region loss is 0.015345986932516098, affinity loss is 0.010647368617355824
# Epoch is [8/20], mini-batch is [245/275], time consumption is 5.304078, batch_loss is 0.025993
# Tue May 23 04:59:15 2023
# region loss is 0.008851778693497181, affinity loss is 0.010779604315757751
# Epoch is [8/20], mini-batch is [246/275], time consumption is 5.755650, batch_loss is 0.019631
# region loss is 0.006645983085036278, affinity loss is 0.007598424330353737
# Epoch is [8/20], mini-batch is [247/275], time consumption is 4.834771, batch_loss is 0.014244
# region loss is 0.005236320663243532, affinity loss is 0.008024461567401886
# Epoch is [8/20], mini-batch is [248/275], time consumption is 3.600548, batch_loss is 0.013261
# region loss is 0.005622754339128733, affinity loss is 0.010458718053996563
# Epoch is [8/20], mini-batch is [249/275], time consumption is 4.143812, batch_loss is 0.016081
# region loss is 0.01225309818983078, affinity loss is 0.017625922337174416
# Epoch is [8/20], mini-batch is [250/275], time consumption is 4.102856, batch_loss is 0.029879
# Tue May 23 04:59:40 2023
